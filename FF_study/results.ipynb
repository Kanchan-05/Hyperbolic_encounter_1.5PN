# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py as h
import pandas as pd
import seaborn as sns

# %%
bank_org = h.File('bank_org.hdf','r')

print ('Number of templates in the bank:', len(bank_org['mass1']))
# Out:
# Number of templates in the bank: 439

# %% [markdown]
# # Results
#
# - The results are for 500 injections
# - The output file has mass and spin parameters for the injections

# %%
matchout = 'match_results_20250218_185318.csv'
df_match = pd.read_csv(matchout)

# %%
min(df_match['match']),max(df_match['match'])
# Out:
# (0.9787969986781352, 0.9999999999965308)

# %%
plt.rcParams['font.family'] = 'Times New Roman'
plt.tick_params(axis='both', which='major', labelsize=18)

sns.kdeplot(df_match['match'], cumulative=True)
plt.yscale('log')
plt.xlabel('Fitting Factor',fontsize=20)
plt.ylabel('Cumulative Fraction',fontsize=20)
plt.xlim([0.97,1])
plt.show()
